# %% [markdown]
# # Numpy
# Numpy is the most used Python package for array manipulations. It implements a lot of scientific routines to manipulate array-like objects, including mathematical operations, linear algebra, statistical operations, etc.
# Install the latest version of numpy running:
# ```bash
# $ pip install numpy
# ```
# or
# ```bash
# $ conda install numpy
# ```
# if you are using a conda environment.

# %%
import numpy as np

# %%
# create a 1D array with values from 0 to 1 with a step size of 10**-3
t = np.arange(start=0,stop=1,step=10**-3)

# you can apply a function to each element of the array
f_t = np.sin(5*2*np.pi*t)

# %% [markdown]
# # Plotting in Notebooks
# A popular plotting library in Python is mathplotlib.
# Install the latest version of matplotlib running:
# ```bash
# $ pip install matplotlib
# ```
# or
# ```bash
# $ conda install matplotlib
# ```
# if you are using a conda environment.
#
# In order to use matplotlib in a notebook you must run the magic function `%mathplotlib` before importing the module. This performs the necessary set-up to display the figures correctly. If the magic function is called without arguments the image is displayed in a separate window. To embed the figure in the notebook use: `%mathplotlib inline` or `%mathplotlib notebook` if you want the figure to be interactive.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# The elements of a plot are illustrated in the figure below
# <p align="center">
#   <img src="../imgs/anatomy.png" width=50%/>
# </p>

# %%
# create a figure with a single axes
fig, ax = plt.subplots()

# add the title to the axes
ax.set_title("Sin Funtion")

# set the visibility of the grid
# (by default it is not visible)
ax.grid(visible=True)

# plot the function
ax.plot(t,f_t)
